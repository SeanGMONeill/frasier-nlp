# %%
import aiohttp
import asyncio
import requests
from bs4 import BeautifulSoup
import urllib.parse
import re
import ssl
import json
import os
from cleantext import clean

# %%
BASE_URL = 'http://www.kacl780.net'
CONCURRENT_LIMIT = 5

# %%
def parse_catalog(html_doc):
    soup = BeautifulSoup(html_doc, 'html.parser')
    links = list(map(lambda x: urllib.parse.urljoin(BASE_URL, x.get('href')), soup.select('#rightCol .SeasonList a')))
    return links

# %%
async def fetch_page(session, url, semaphore):
    async with semaphore:
        async with session.get(url) as response:
            return await response.text()

async def fetch_pages(urls):
    async with aiohttp.ClientSession() as session:
        semaphore = asyncio.Semaphore(CONCURRENT_LIMIT)
        results = await asyncio.gather(*[fetch_page(session, url, semaphore) for url in urls], return_exceptions=True)
        return results

# %%
def split_title(title_string):
    #Example input: '[2.1]Slow Tango In South Seattle'
    title_string = title_string.strip()
    season_ep = re.match(r"\[(\d+\.\d+).*\]",  title_string)[1]
    season, episode = season_ep.split('.')
    season, episode = int(season), int(episode)
    title = title_string.split(']')[1].strip()
    return {'season': season, 'episode': episode, 'title': title}

# %%
def get_speech(transcript):
    reg = re.compile('\n *\w+:')
    transcript = re.sub(re.compile('\[(.|\n)*?\]'), '', transcript)
    dialogue = reg.split(transcript)[1:]
    speech_tags = list(map(lambda x: x.strip().replace(':',''), reg.findall(transcript)))
    speech = [{'character': character, 'line': line} for character, line in zip(speech_tags, dialogue)]
    linetab = re.compile('[\n\t\r ]+')
    for x in speech:
        x['line'] = re.compile('\n\n').split(x['line'])[0]
        x['line'] = re.sub(linetab, ' ', x['line']).strip()
    speech = list(filter(lambda x: len(x['line']) > 0, speech))
    return speech

# %%
def parse_transcript_page(html_doc):
    soup = BeautifulSoup(html_doc, 'html.parser')
    try:
        title_text = soup.select_one('#rightCol h1').text
    except:
        title_text = soup.select_one('#rightCol h2').text
    data = split_title(title_text)
    try:
        transcript = list(filter(lambda x: x.find(string=re.compile('(Transcript|Quotes & Scene Summary)')), soup.select('#rightCol h2')))[0].find_next_sibling('pre').get_text(' ')
    except:
        transcript = soup.find(string=re.compile('^(ACT|Act)'))
    data['transcript'] = transcript#.text.replace('\n','')#clean(transcript, lower=False, to_ascii=False)
    data['dialogue'] = get_speech(data['transcript'])
    return data

# %%
r = requests.get('http://www.kacl780.net/frasier/transcripts/')
urls = parse_catalog(r.text)

responses = await fetch_pages(urls)

# %%
transcripts = list(map(lambda x: parse_transcript_page(x), responses))
for script in transcripts:
    filepath = 'data/site=kacl780/season={season}/Frasier_{season}x{episode}.json'.format(season=script['season'], episode=script['episode'])
    os.makedirs(os.path.dirname(filepath), exist_ok=True)
    with open(filepath, 'w') as file:
        json.dump(script, file)
        print(filepath)
# Out:
# data/site=kacl780/season=1/Frasier_1x1.json
# data/site=kacl780/season=1/Frasier_1x2.json
# data/site=kacl780/season=1/Frasier_1x3.json
# data/site=kacl780/season=1/Frasier_1x4.json
# data/site=kacl780/season=1/Frasier_1x5.json
# data/site=kacl780/season=1/Frasier_1x6.json
# data/site=kacl780/season=1/Frasier_1x7.json
# data/site=kacl780/season=1/Frasier_1x8.json
# data/site=kacl780/season=1/Frasier_1x9.json
# data/site=kacl780/season=1/Frasier_1x10.json
# data/site=kacl780/season=1/Frasier_1x11.json
# data/site=kacl780/season=1/Frasier_1x12.json
# data/site=kacl780/season=1/Frasier_1x13.json
# data/site=kacl780/season=1/Frasier_1x14.json
# data/site=kacl780/season=1/Frasier_1x15.json
# data/site=kacl780/season=1/Frasier_1x16.json
# data/site=kacl780/season=1/Frasier_1x17.json
# data/site=kacl780/season=1/Frasier_1x18.json
# data/site=kacl780/season=1/Frasier_1x19.json
# data/site=kacl780/season=1/Frasier_1x20.json
# data/site=kacl780/season=1/Frasier_1x21.json
# data/site=kacl780/season=1/Frasier_1x22.json
# data/site=kacl780/season=1/Frasier_1x23.json
# data/site=kacl780/season=1/Frasier_1x24.json
# data/site=kacl780/season=2/Frasier_2x1.json
# data/site=kacl780/season=2/Frasier_2x2.json
# data/site=kacl780/season=2/Frasier_2x3.json
# data/site=kacl780/season=2/Frasier_2x4.json
# data/site=kacl780/season=2/Frasier_2x5.json
# data/site=kacl780/season=2/Frasier_2x6.json
# data/site=kacl780/season=2/Frasier_2x7.json
# data/site=kacl780/season=2/Frasier_2x8.json
# data/site=kacl780/season=2/Frasier_2x9.json
# data/site=kacl780/season=2/Frasier_2x10.json
# data/site=kacl780/season=2/Frasier_2x11.json
# data/site=kacl780/season=2/Frasier_2x12.json
# data/site=kacl780/season=2/Frasier_2x13.json
# data/site=kacl780/season=2/Frasier_2x14.json
# data/site=kacl780/season=2/Frasier_2x15.json
# data/site=kacl780/season=2/Frasier_2x16.json
# data/site=kacl780/season=2/Frasier_2x17.json
# data/site=kacl780/season=2/Frasier_2x18.json
# data/site=kacl780/season=2/Frasier_2x19.json
# data/site=kacl780/season=2/Frasier_2x20.json
# data/site=kacl780/season=2/Frasier_2x21.json
# data/site=kacl780/season=2/Frasier_2x22.json
# data/site=kacl780/season=2/Frasier_2x23.json
# data/site=kacl780/season=2/Frasier_2x24.json
# data/site=kacl780/season=3/Frasier_3x1.json
# data/site=kacl780/season=3/Frasier_3x2.json
# data/site=kacl780/season=3/Frasier_3x3.json
# data/site=kacl780/season=3/Frasier_3x4.json
# data/site=kacl780/season=3/Frasier_3x5.json
# data/site=kacl780/season=3/Frasier_3x6.json
# data/site=kacl780/season=3/Frasier_3x7.json
# data/site=kacl780/season=3/Frasier_3x8.json
# data/site=kacl780/season=3/Frasier_3x9.json
# data/site=kacl780/season=3/Frasier_3x10.json
# data/site=kacl780/season=3/Frasier_3x11.json
# data/site=kacl780/season=3/Frasier_3x12.json
# data/site=kacl780/season=3/Frasier_3x13.json
# data/site=kacl780/season=3/Frasier_3x14.json
# data/site=kacl780/season=3/Frasier_3x15.json
# data/site=kacl780/season=3/Frasier_3x16.json
# data/site=kacl780/season=3/Frasier_3x17.json
# data/site=kacl780/season=3/Frasier_3x18.json
# data/site=kacl780/season=3/Frasier_3x19.json
# data/site=kacl780/season=3/Frasier_3x20.json
# data/site=kacl780/season=3/Frasier_3x21.json
# data/site=kacl780/season=3/Frasier_3x22.json
# data/site=kacl780/season=3/Frasier_3x23.json
# data/site=kacl780/season=3/Frasier_3x24.json
# data/site=kacl780/season=4/Frasier_4x1.json
# data/site=kacl780/season=4/Frasier_4x2.json
# data/site=kacl780/season=4/Frasier_4x3.json
# data/site=kacl780/season=4/Frasier_4x4.json
# data/site=kacl780/season=4/Frasier_4x5.json
# data/site=kacl780/season=4/Frasier_4x6.json
# data/site=kacl780/season=4/Frasier_4x7.json
# data/site=kacl780/season=4/Frasier_4x8.json
# data/site=kacl780/season=4/Frasier_4x9.json
# data/site=kacl780/season=4/Frasier_4x10.json
# data/site=kacl780/season=4/Frasier_4x11.json
# data/site=kacl780/season=4/Frasier_4x12.json
# data/site=kacl780/season=4/Frasier_4x13.json
# data/site=kacl780/season=4/Frasier_4x14.json
# data/site=kacl780/season=4/Frasier_4x15.json
# data/site=kacl780/season=4/Frasier_4x16.json
# data/site=kacl780/season=4/Frasier_4x17.json
# data/site=kacl780/season=4/Frasier_4x18.json
# data/site=kacl780/season=4/Frasier_4x19.json
# data/site=kacl780/season=4/Frasier_4x20.json
# data/site=kacl780/season=4/Frasier_4x21.json
# data/site=kacl780/season=4/Frasier_4x22.json
# data/site=kacl780/season=4/Frasier_4x23.json
# data/site=kacl780/season=4/Frasier_4x24.json
# data/site=kacl780/season=5/Frasier_5x1.json
# data/site=kacl780/season=5/Frasier_5x2.json
# data/site=kacl780/season=5/Frasier_5x3.json
# data/site=kacl780/season=5/Frasier_5x4.json
# data/site=kacl780/season=5/Frasier_5x5.json
# data/site=kacl780/season=5/Frasier_5x6.json
# data/site=kacl780/season=5/Frasier_5x7.json
# data/site=kacl780/season=5/Frasier_5x8.json
# data/site=kacl780/season=5/Frasier_5x9.json
# data/site=kacl780/season=5/Frasier_5x10.json
# data/site=kacl780/season=5/Frasier_5x11.json
# data/site=kacl780/season=5/Frasier_5x12.json
# data/site=kacl780/season=5/Frasier_5x13.json
# data/site=kacl780/season=5/Frasier_5x14.json
# data/site=kacl780/season=5/Frasier_5x15.json
# data/site=kacl780/season=5/Frasier_5x16.json
# data/site=kacl780/season=5/Frasier_5x17.json
# data/site=kacl780/season=5/Frasier_5x18.json
# data/site=kacl780/season=5/Frasier_5x19.json
# data/site=kacl780/season=5/Frasier_5x20.json
# data/site=kacl780/season=5/Frasier_5x21.json
# data/site=kacl780/season=5/Frasier_5x22.json
# data/site=kacl780/season=5/Frasier_5x23.json
# data/site=kacl780/season=5/Frasier_5x24.json
# data/site=kacl780/season=6/Frasier_6x1.json
# data/site=kacl780/season=6/Frasier_6x2.json
# data/site=kacl780/season=6/Frasier_6x3.json
# data/site=kacl780/season=6/Frasier_6x4.json
# data/site=kacl780/season=6/Frasier_6x5.json
# data/site=kacl780/season=5/Frasier_5x5.json
# data/site=kacl780/season=6/Frasier_6x7.json
# data/site=kacl780/season=6/Frasier_6x8.json
# data/site=kacl780/season=6/Frasier_6x9.json
# data/site=kacl780/season=6/Frasier_6x10.json
# data/site=kacl780/season=6/Frasier_6x11.json
# data/site=kacl780/season=6/Frasier_6x12.json
# data/site=kacl780/season=6/Frasier_6x13.json
# data/site=kacl780/season=6/Frasier_6x14.json
# data/site=kacl780/season=6/Frasier_6x15.json
# data/site=kacl780/season=6/Frasier_6x16.json
# data/site=kacl780/season=6/Frasier_6x17.json
# data/site=kacl780/season=6/Frasier_6x18.json
# data/site=kacl780/season=6/Frasier_6x19.json
# data/site=kacl780/season=6/Frasier_6x20.json
# data/site=kacl780/season=6/Frasier_6x21.json
# data/site=kacl780/season=6/Frasier_6x22.json
# data/site=kacl780/season=6/Frasier_6x23.json
# data/site=kacl780/season=6/Frasier_6x24.json
# data/site=kacl780/season=7/Frasier_7x1.json
# data/site=kacl780/season=7/Frasier_7x2.json
# data/site=kacl780/season=7/Frasier_7x3.json
# data/site=kacl780/season=7/Frasier_7x4.json
# data/site=kacl780/season=7/Frasier_7x5.json
# data/site=kacl780/season=7/Frasier_7x6.json
# data/site=kacl780/season=7/Frasier_7x7.json
# data/site=kacl780/season=7/Frasier_7x8.json
# data/site=kacl780/season=7/Frasier_7x9.json
# data/site=kacl780/season=7/Frasier_7x10.json
# data/site=kacl780/season=7/Frasier_7x11.json
# data/site=kacl780/season=7/Frasier_7x12.json
# data/site=kacl780/season=7/Frasier_7x13.json
# data/site=kacl780/season=7/Frasier_7x14.json
# data/site=kacl780/season=7/Frasier_7x15.json
# data/site=kacl780/season=7/Frasier_7x16.json
# data/site=kacl780/season=7/Frasier_7x17.json
# data/site=kacl780/season=7/Frasier_7x18.json
# data/site=kacl780/season=7/Frasier_7x19.json
# data/site=kacl780/season=7/Frasier_7x20.json
# data/site=kacl780/season=7/Frasier_7x21.json
# data/site=kacl780/season=7/Frasier_7x22.json
# data/site=kacl780/season=7/Frasier_7x23.json
# data/site=kacl780/season=7/Frasier_7x24.json
# data/site=kacl780/season=8/Frasier_8x1.json
# data/site=kacl780/season=8/Frasier_8x2.json
# data/site=kacl780/season=8/Frasier_8x3.json
# data/site=kacl780/season=8/Frasier_8x4.json
# data/site=kacl780/season=8/Frasier_8x5.json
# data/site=kacl780/season=8/Frasier_8x6.json
# data/site=kacl780/season=8/Frasier_8x7.json
# data/site=kacl780/season=8/Frasier_8x8.json
# data/site=kacl780/season=8/Frasier_8x9.json
# data/site=kacl780/season=8/Frasier_8x10.json
# data/site=kacl780/season=8/Frasier_8x11.json
# data/site=kacl780/season=8/Frasier_8x12.json
# data/site=kacl780/season=8/Frasier_8x13.json
# data/site=kacl780/season=8/Frasier_8x14.json
# data/site=kacl780/season=8/Frasier_8x15.json
# data/site=kacl780/season=8/Frasier_8x16.json
# data/site=kacl780/season=8/Frasier_8x17.json
# data/site=kacl780/season=8/Frasier_8x18.json
# data/site=kacl780/season=8/Frasier_8x19.json
# data/site=kacl780/season=8/Frasier_8x20.json
# data/site=kacl780/season=8/Frasier_8x21.json
# data/site=kacl780/season=8/Frasier_8x22.json
# data/site=kacl780/season=8/Frasier_8x23.json
# data/site=kacl780/season=8/Frasier_8x24.json
# data/site=kacl780/season=9/Frasier_9x1.json
# data/site=kacl780/season=9/Frasier_9x2.json
# data/site=kacl780/season=9/Frasier_9x3.json
# data/site=kacl780/season=9/Frasier_9x4.json
# data/site=kacl780/season=9/Frasier_9x5.json
# data/site=kacl780/season=9/Frasier_9x6.json
# data/site=kacl780/season=9/Frasier_9x7.json
# data/site=kacl780/season=9/Frasier_9x8.json
# data/site=kacl780/season=9/Frasier_9x9.json
# data/site=kacl780/season=9/Frasier_9x10.json
# data/site=kacl780/season=9/Frasier_9x11.json
# data/site=kacl780/season=9/Frasier_9x12.json
# data/site=kacl780/season=9/Frasier_9x13.json
# data/site=kacl780/season=9/Frasier_9x14.json
# data/site=kacl780/season=9/Frasier_9x15.json
# data/site=kacl780/season=9/Frasier_9x16.json
# data/site=kacl780/season=9/Frasier_9x17.json
# data/site=kacl780/season=9/Frasier_9x18.json
# data/site=kacl780/season=9/Frasier_9x19.json
# data/site=kacl780/season=9/Frasier_9x20.json
# data/site=kacl780/season=9/Frasier_9x21.json
# data/site=kacl780/season=9/Frasier_9x22.json
# data/site=kacl780/season=9/Frasier_9x23.json
# data/site=kacl780/season=9/Frasier_9x24.json
# data/site=kacl780/season=10/Frasier_10x1.json
# data/site=kacl780/season=10/Frasier_10x2.json
# data/site=kacl780/season=10/Frasier_10x3.json
# data/site=kacl780/season=10/Frasier_10x4.json
# data/site=kacl780/season=10/Frasier_10x5.json
# data/site=kacl780/season=10/Frasier_10x6.json
# data/site=kacl780/season=10/Frasier_10x7.json
# data/site=kacl780/season=10/Frasier_10x8.json
# data/site=kacl780/season=10/Frasier_10x9.json
# data/site=kacl780/season=10/Frasier_10x10.json
# data/site=kacl780/season=10/Frasier_10x11.json
# data/site=kacl780/season=10/Frasier_10x12.json
# data/site=kacl780/season=10/Frasier_10x13.json
# data/site=kacl780/season=10/Frasier_10x14.json
# data/site=kacl780/season=10/Frasier_10x15.json
# data/site=kacl780/season=10/Frasier_10x16.json
# data/site=kacl780/season=10/Frasier_10x17.json
# data/site=kacl780/season=10/Frasier_10x18.json
# data/site=kacl780/season=10/Frasier_10x19.json
# data/site=kacl780/season=10/Frasier_10x20.json
# data/site=kacl780/season=10/Frasier_10x21.json
# data/site=kacl780/season=10/Frasier_10x22.json
# data/site=kacl780/season=10/Frasier_10x23.json
# data/site=kacl780/season=10/Frasier_10x24.json
# data/site=kacl780/season=11/Frasier_11x1.json
# data/site=kacl780/season=11/Frasier_11x2.json
# data/site=kacl780/season=11/Frasier_11x3.json
# data/site=kacl780/season=11/Frasier_11x4.json
# data/site=kacl780/season=11/Frasier_11x5.json
# data/site=kacl780/season=11/Frasier_11x6.json
# data/site=kacl780/season=11/Frasier_11x7.json
# data/site=kacl780/season=11/Frasier_11x8.json
# data/site=kacl780/season=11/Frasier_11x9.json
# data/site=kacl780/season=11/Frasier_11x10.json
# data/site=kacl780/season=11/Frasier_11x11.json
# data/site=kacl780/season=11/Frasier_11x12.json
# data/site=kacl780/season=11/Frasier_11x13.json
# data/site=kacl780/season=11/Frasier_11x14.json
# data/site=kacl780/season=11/Frasier_11x15.json
# data/site=kacl780/season=11/Frasier_11x16.json
# data/site=kacl780/season=11/Frasier_11x17.json
# data/site=kacl780/season=11/Frasier_11x18.json
# data/site=kacl780/season=11/Frasier_11x19.json
# data/site=kacl780/season=11/Frasier_11x20.json
# data/site=kacl780/season=11/Frasier_11x21.json
# data/site=kacl780/season=11/Frasier_11x22.json
# data/site=kacl780/season=11/Frasier_11x23.json
# data/site=kacl780/season=11/Frasier_11x24.json
